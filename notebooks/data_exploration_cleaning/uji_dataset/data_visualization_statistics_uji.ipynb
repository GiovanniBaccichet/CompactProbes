# %% [markdown]
# # Data Visualization and Statistics for the UJI Probe Dataset

# %% [markdown]
# This package contains an anonymized packets of 802.11 probe requests captured throughout March of 2023 at Universitat Jaume I. The packet capture file is in the standardized *.pcap binary format and can be opened with any packet analysis tool such as Wireshark or scapy (Python packet analysis and manipulation package).
#
# The dataset is usable for analyzis of Wi-Fi probe requests, presence detection, occupancy estimation or signal stability analyzis.

# %% [markdown]
# [Download](https://zenodo.org/records/7801798)

# %% [markdown]
# ## Libraries and Configurations

# %% [markdown]
# Import configuration files

# %%
from configparser import ConfigParser

config = ConfigParser()
config.read("../config.ini")
# Out:
# ['../config.ini']

# %% [markdown]
# Import **data libraries**

# %%
import pandas as pd

# %% [markdown]
# Import **other libraries**

# %%
from rich.progress import Progress
from rich import traceback

traceback.install()
# Out:
# <bound method InteractiveShell.excepthook of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x106722490>>

# %% [markdown]
# Custom helper scripts

# %%
# %cd ..
from scripts import plotHelper, encodingHelper
# %cd data_exploration_cleaning
# Out:
# /Users/bacci/Library/CloudStorage/SynologyDrive-giovanni/Research 🌱/Repositories/COMPACT/notebooks
# /Users/bacci/Library/CloudStorage/SynologyDrive-giovanni/Research 🌱/Repositories/COMPACT/notebooks/data_exploration_cleaning

# %% [markdown]
# ## Import Data

# %%
# Combined dataframe
uji_df_csv = config["UJI"]["extracted_path"] + "/uji_probes.csv"

# %%
uji_df = pd.read_csv(uji_df_csv)
uji_df["Timestamp"] = pd.to_datetime(uji_df["Timestamp"], unit="s")

# %% [markdown]
# Since the dataset is not labelled, we can drop the `Label` column

# %%
uji_df.drop(columns=["Label"], inplace=True)

# %% [markdown]
# Filling empty fields with `-1`

# %%
uji_df.fillna(-1, inplace=True)

# %% [markdown]
# ## Statistics

# %%
print("Number of unique MAC Addresses", uji_df["MAC Address"].nunique())
# Out:
# Number of unique MAC Addresses 129330

# %% [markdown]
# ### Information Elements

# %%
print("Number of unique HT Capabilities", uji_df["HT Capabilities"].nunique())
# Out:
# Number of unique HT Capabilities 209

# %%
print("Number of unique VHT Capabilities", uji_df["VHT Capabilities"].nunique())
# Out:
# Number of unique VHT Capabilities 55

# %%
print("Number of unique HE Capabilities", uji_df["HE Capabilities"].nunique())
# Out:
# Number of unique HE Capabilities 162

# %%
print("Number of unique Supported Rates", uji_df["Supported Rates"].nunique())
# Out:
# Number of unique Supported Rates 23

# %%
print(
    "Number of unique Extended Supported Rates",
    uji_df["Extended Supported Rates"].nunique(),
)
# Out:
# Number of unique Extended Supported Rates 13

# %% [markdown]
# ## SSID Field

# %%
plotHelper.plot_pie_chart(uji_df, "SSID")

# %% [markdown]
# Since the `SSID` field is empty most of the time, we drop the column

# %%
uji_df.drop(columns=["SSID"], inplace=True)

# %%
uji_df
# Out:
#                             Timestamp        MAC Address  Channel  DS Channel  \
# 0       2023-02-28 10:06:13.608247995  16:d2:8e:2a:d5:47        6         5.0
# 1       2023-02-28 10:06:13.619611979  16:d2:8e:2a:d5:47        6         5.0
# 2       2023-02-28 10:06:15.874474049  aa:a2:d1:e3:8c:22        6         6.0
# 3       2023-02-28 10:06:17.232656956  86:6f:da:1b:96:4b        9         8.0
# 4       2023-02-28 10:06:17.326913118  60:83:34:df:f8:74       10         9.0
# ...                               ...                ...      ...         ...
# 1410829 2023-03-29 10:36:00.696099997  c6:6f:dd:56:6d:7e       11        10.0
# 1410830 2023-03-29 10:36:00.717555046  c6:6f:dd:56:6d:7e       11        10.0
# 1410831 2023-03-29 10:36:00.722501040  c6:6f:dd:56:6d:7e       11        10.0
# 1410832 2023-03-29 10:36:03.044989109  ce:1c:b2:ac:5c:9c        2         1.0
# 1410833 2023-03-29 10:36:04.293812037  3a:6e:47:5f:5e:9a        3         2.0
#
#                                            HT Capabilities  \
# 0        2d4017ff00000000000000000000000000000000000000...
# 1        2d4017ff00000000000000000000000000000000000000...
# 2        2d4017ff00000000000000000000000000000000000000...
# 3        2d0917ff00000000000000000000000000000000000000...
# 4        2c0103ff00000000000000000000000000000000000000...
# ...                                                    ...
# 1410829  ef0113ffff000000000000000000000000000000000000...
# 1410830  ef0113ffff000000000000000000000000000000000000...
# 1410831  ef0113ffff000000000000000000000000000000000000...
# 1410832  ad0917ffff000000000000000000000000000000000000...
# 1410833  ad0113ffff000000000000000000000000000000000000...
#
#           Extended Capabilities    Vendor Specific Tags   Supported Rates  \
# 0              0000080400000040  0017f20a00010400000000          02040b16
# 1              0000080400000040  0017f20a00010400000000          02040b16
# 2              0000080400000040  0017f20a00010400000000          02040b16
# 3            050008800000004080          0050f208001200  02040b160c121824
# 4                            -1          0050f208000000          02040b16
# ...                         ...                     ...               ...
# 1410829  00000a8200400000000120          0050f208002800          02040b16
# 1410830  00000a8200400000000120          0050f208002800          02040b16
# 1410831  00000a8200400000000120          0050f208002800          02040b16
# 1410832  04000a8201400040802120          0050f208002a00          02040b16
# 1410833    00000a82004000000001          0050f208002800          02040b16
#
#         Extended Supported Rates          VHT Capabilities  \
# 0               0c1218243048606c                        -1
# 1               0c1218243048606c                        -1
# 2               0c1218243048606c                        -1
# 3                       3048606c                        -1
# 4               0c1218243048606c                        -1
# ...                          ...                       ...
# 1410829         0c1218243048606c  92f19033faff6203faff6203
# 1410830         0c1218243048606c  92f19033faff6203faff6203
# 1410831         0c1218243048606c  92f19033faff6203faff6203
# 1410832         0c1218243048606c  92f99133faff0c03faff0c03
# 1410833         0c1218243048606c  92f99133faff6203faff6203
#
#                                            HE Capabilities  Length
# 0                                                       -1     145
# 1                                                       -1     145
# 2                                                       -1     145
# 3                                                       -1     107
# 4                                                       -1     109
# ...                                                    ...     ...
# 1410829                                             020028     163
# 1410830                                             020014     150
# 1410831                                             020013     163
# 1410832  2303010082400004334c890d0180c8000c00fafffaff19...     168
# 1410833                                             020017     149
#
# [1410834 rows x 12 columns]

# %%
dataset_probes_total = uji_df.shape[0]

# %% [markdown]
# Dropping rows having a locally administered `MAC Address`: the 2nd digit of locally assigned MAC address in hexadecimal format has only four options: **2** (0010), **6** (0110), **A** (1010) or **E** (1110).

# %%
uji_df = uji_df.loc[~uji_df["MAC Address"].str[1].isin(["2", "6", "a", "e"]), :]

# %%
uji_df
# Out:
#                             Timestamp        MAC Address  Channel  DS Channel  \
# 4       2023-02-28 10:06:17.326913118  60:83:34:df:f8:74       10         9.0
# 5       2023-02-28 10:06:17.327796936  60:83:34:df:f8:74       10         9.0
# 6       2023-02-28 10:06:17.336941957  60:83:34:df:f8:74       10         9.0
# 7       2023-02-28 10:06:25.303733110  48:5f:99:07:10:21        2        -1.0
# 8       2023-02-28 10:06:25.305162907  48:5f:99:07:10:21        2        -1.0
# ...                               ...                ...      ...         ...
# 1410798 2023-03-29 10:35:45.241776943  28:39:26:b4:51:55       11        -1.0
# 1410799 2023-03-29 10:35:45.242811918  28:39:26:b4:51:55       11        -1.0
# 1410800 2023-03-29 10:35:45.248949051  28:39:26:b4:51:55       11        -1.0
# 1410801 2023-03-29 10:35:45.250413895  28:39:26:b4:51:55       11        -1.0
# 1410802 2023-03-29 10:35:45.257093905  28:39:26:b4:51:55       11        -1.0
#
#                                            HT Capabilities  \
# 4        2c0103ff00000000000000000000000000000000000000...
# 5        2c0103ff00000000000000000000000000000000000000...
# 6        2c0103ff00000000000000000000000000000000000000...
# 7        ef1902ffff000000000000000000000000000000000000...
# 8        ef1902ffff000000000000000000000000000000000000...
# ...                                                    ...
# 1410798  ad09020000000000000000000000000000000000000000...
# 1410799  ad09020000000000000000000000000000000000000000...
# 1410800  ad09020000000000000000000000000000000000000000...
# 1410801  ad09020000000000000000000000000000000000000000...
# 1410802  ad09020000000000000000000000000000000000000000...
#
#         Extended Capabilities Vendor Specific Tags   Supported Rates  \
# 4                          -1       0050f208000000          02040b16
# 5                          -1       0050f208000000          02040b16
# 6                          -1       0050f208000000          02040b16
# 7          000000000000000000                   -1  82848b960c121824
# 8          000000000000000000                   -1  82848b960c121824
# ...                       ...                  ...               ...
# 1410798    000008000000000000                   -1  82848b960c121824
# 1410799    000008000000000000                   -1  82848b960c121824
# 1410800    000008000000000000                   -1  82848b960c121824
# 1410801    000008000000000000                   -1  82848b960c121824
# 1410802    000008000000000000                   -1  82848b960c121824
#
#         Extended Supported Rates VHT Capabilities HE Capabilities  Length
# 4               0c1218243048606c               -1              -1     109
# 5               0c1218243048606c               -1              -1      96
# 6               0c1218243048606c               -1              -1     109
# 7                       3048606c               -1              -1     102
# 8                       3048606c               -1              -1     102
# ...                          ...              ...             ...     ...
# 1410798                 3048606c               -1              -1     102
# 1410799                 3048606c               -1              -1     102
# 1410800                 3048606c               -1              -1     102
# 1410801                 3048606c               -1              -1     102
# 1410802                 3048606c               -1              -1     102
#
# [918054 rows x 12 columns]

# %%
dataset_probes_non_random = uji_df.shape[0]

# %%
print(
    "Percentage of non-random MAC Addresses",
    (dataset_probes_non_random / dataset_probes_total) * 100,
    "%",
)
# Out:
# Percentage of non-random MAC Addresses 65.07172353373963 %

# %%
print("Number of unique NON randomized MAC Addresses", uji_df["MAC Address"].nunique())
# Out:
# Number of unique NON randomized MAC Addresses 2437

# %%
print(
    "Average number of probes per unique MAC Address",
    uji_df.groupby("MAC Address").size().mean(),
)
# Out:
# Average number of probes per unique MAC Address 376.7148132950349

# %% [markdown]
# ## Label Encoding

# %%
# Iterate over each column in the dataframe
for column in uji_df.columns:
    # Check if the column is of object type
    if uji_df[column].dtype == "object":
        # Convert the column to string type
        uji_df[column] = uji_df[column].astype(str)
        # Label encode the column
        uji_df[column] = label_encoder.fit_transform(uji_df[column])
# Out:
# /var/folders/kz/mqbx964j4w53vxgzd7rlzx380000gn/T/ipykernel_18113/2164050177.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   uji_df[column] = uji_df[column].astype(str)
# /var/folders/kz/mqbx964j4w53vxgzd7rlzx380000gn/T/ipykernel_18113/2164050177.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   uji_df[column] = label_encoder.fit_transform(uji_df[column])
# /var/folders/kz/mqbx964j4w53vxgzd7rlzx380000gn/T/ipykernel_18113/2164050177.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   uji_df[column] = uji_df[column].astype(str)
# /var/folders/kz/mqbx964j4w53vxgzd7rlzx380000gn/T/ipykernel_18113/2164050177.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   uji_df[column] = label_encoder.fit_transform(uji_df[column])
# /var/folders/kz/mqbx964j4w53vxgzd7rlzx380000gn/T/ipykernel_18113/2164050177.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   uji_df[column] = uji_df[column].astype(str)
# /var/folders/kz/mqbx964j4w53vxgzd7rlzx380000gn/T/ipykernel_18113/2164050177.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   uji_df[column] = label_encoder.fit_transform(uji_df[column])
# /var/folders/kz/mqbx964j4w53vxgzd7rlzx380000gn/T/ipykernel_18113/2164050177.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   uji_df[column] = uji_df[column].astype(str)
# /var/folders/kz/mqbx964j4w53vxgzd7rlzx380000gn/T/ipykernel_18113/2164050177.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   uji_df[column] = label_encoder.fit_transform(uji_df[column])
# /var/folders/kz/mqbx964j4w53vxgzd7rlzx380000gn/T/ipykernel_18113/2164050177.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   uji_df[column] = uji_df[column].astype(str)
# /var/folders/kz/mqbx964j4w53vxgzd7rlzx380000gn/T/ipykernel_18113/2164050177.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   uji_df[column] = label_encoder.fit_transform(uji_df[column])
# /var/folders/kz/mqbx964j4w53vxgzd7rlzx380000gn/T/ipykernel_18113/2164050177.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   uji_df[column] = uji_df[column].astype(str)
# /var/folders/kz/mqbx964j4w53vxgzd7rlzx380000gn/T/ipykernel_18113/2164050177.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   uji_df[column] = label_encoder.fit_transform(uji_df[column])
# /var/folders/kz/mqbx964j4w53vxgzd7rlzx380000gn/T/ipykernel_18113/2164050177.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   uji_df[column] = uji_df[column].astype(str)
# /var/folders/kz/mqbx964j4w53vxgzd7rlzx380000gn/T/ipykernel_18113/2164050177.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   uji_df[column] = label_encoder.fit_transform(uji_df[column])
# /var/folders/kz/mqbx964j4w53vxgzd7rlzx380000gn/T/ipykernel_18113/2164050177.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   uji_df[column] = uji_df[column].astype(str)
# /var/folders/kz/mqbx964j4w53vxgzd7rlzx380000gn/T/ipykernel_18113/2164050177.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   uji_df[column] = label_encoder.fit_transform(uji_df[column])

# %%
to_drop = ["Timestamp", "MAC Address"]

# %%
uji_df.drop(columns=to_drop, inplace=True)
# Out:
# /var/folders/kz/mqbx964j4w53vxgzd7rlzx380000gn/T/ipykernel_18113/3893458755.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   uji_df.drop(columns=to_drop, inplace=True)

# %%
plotHelper.plot_correlation_matrix(uji_df)
